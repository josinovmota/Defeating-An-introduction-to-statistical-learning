# %% [markdown]
# # Questão 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# O p-value, normalmente, quando tem um valor menor do que 0.05, nega a Null Hypothesis do predictor. Nesse caso, podemos 
# observar que os predictors TV e radio tem um p-value menor que 0.05, evidenciando assim, que esses 2 predictors não são
# Null Hypothesis, já o Newspaper tem um p-value consideravelmente alto, o que nos indica que ele muito provavelmente é
# um Null Hypothesis e não agrega no nosso modelo.

# %% [markdown]
# # Questão 2

# %%
# Ambos são técnicas de machine learning do método KNN, que se baseia em escolher um X_0 e, à partir do número K dado,  
# procurar nos K valores ou palavras que estão mais próximos desse X_0. No caso do KNN Regression, são normalmente usado números, e por
# meio da menor distância euclidiana entre o X_0 e o K pontos, são formados os grupos que esse algorítmo 
# busca. Já o KNN classifier é usado para dados Categóricos, como por exemplo, para identificar quais emails são SPAM  
# ou não, e por ser do mesmo algorítmo KNN, também busca os items mais próximos do que escolhemos como sendo nosso X_0.

# %% [markdown]
# # Questão 3

# %% [markdown]
# # a)

# %%
# i. Errada, já que para valores fixos, College vai multiplicar o valor fixo por 1, enquanto High School, por 0.

# ii. Correta, eles recebem, em média, 35000 à mais do que os que terminaram a High School.

# iii. Correta. É um pouco complexo de entender de início, porém, ao observarmos a interação entre GPA e LEVEL, que, nesse caso
# é o B_hat_5, podemos ver que quando temos GPA iguais para ambos college e high school, o College recebe -10 mil dólares do que
# o high school. A pergunta fala que, caso o GPA seja maior, é possível que um High School receba mais do que um College? E sim,
# é possível, já que com 3.5 unidades à mais de GPA, os valores iriam se igualar, fazendo assim entender que com mais de 3.5 unidades
# um High School poderia ganhar mais que um college, mas sempre lembrando que os outros valores também podem afetar.

# iv. Incorreta, já que quanto maior o GPA, para valores fixos, menos o que o College ganha.

# %% [markdown]
# # b)

# %%
# O exercício pede pra prevermos o salário de um College Graduate com 110 de QI e 4 de GPA
def predict_salary(Qi: int, GPA: int, Type: int):

    B_hat_QI: float = 0.07
    B_hat_GPA: int = 20
    B_hat_3: int = 35
    B_hat_4: float = 0.01
    B_hat_5: int = -10
    B_hat_0: int = 50

    Sallary: int = 1000

# Importante ressaltar que todos os predictors devem ser multiplicados pelo B_hat value
    Final_Value = ((B_hat_QI * Qi + B_hat_GPA * GPA + B_hat_3 * Type + B_hat_4 * (Qi*GPA) + B_hat_5 * (Type*GPA) + B_hat_0) * Sallary)
    Formated_Final_Value = "R$ {:.0f}".format(Final_Value)
    return(print(Formated_Final_Value))

predict_salary(110, 4, 1)
# Out:
# R$ 137100

# %% [markdown]
# # c)

# %%
# Sinergy Effect | Interaction Effect.
# False. Dado que eu não tenho acesso às informações como P-value e F-statistics, não posso inferir muitas coisas porém, 
# como dado no exemplo da questão anterior, aonde o aluno tinha 110 de QI e 4 de GPA, o interaction term aumentaria 4.4 
# mil dólares no resultado, o que é um valor bem alto

# %% [markdown]
# # Questão 4

# %%
# N = 100. Cubic Regression é normalmente Urbanada quando os dados não são lineares, aí tentamos fazer outras aproximações 
# afim de ter um modelo least squares com erros menores.

# %% [markdown]
# # a)

# %%
# Sim, dado que a True Relationship é linear, esperamos que os erros da Cubic Regression sejam maiores.

# %% [markdown]
# # b)

# %%
# Bom, como dito na questão anterior, pela True Relationship ser linear, uma aproximação cúbica, sendo diferente de uma 
# aproximação de primeiro grau (Que forma uma linha) Vai tender a ser pior, dado que a cúbica tende a ser mais Flexível
# e o que estamos bUrbancando é uma reta

# %% [markdown]
# # c)

# %%
# Sim, esperamos que a Regressão Linear tenha um RSS maior, dado que os nossos dados não são Lineares. Eles não são iguais
# por serem abordagens diferentes. Enquanto um forma uma linha, o outro forma algo mais Flexível e dado que os valores não
# são lineares, podemos assumir que 1 terá mais dificuldade em chegar na True Relationship do que o outro. Não tem uma
# informação muito precisa, mas mesmo assim podemos assumir algumas coisas.

# %% [markdown]
# # d)

# %%
# Os dados não são lineares, então uma regressão linear que forma uma Linha não terá um RSS baixo para esses dados.
# Já a cúbica, por flexível, tende a provavelmente se encaixar melhor nos dados.

# %% [markdown]
# # Questão 5

# %%
# Muito difícil pra mim :(

# %% [markdown]
# # Questão 6

# %%
# É bem intuitivo pensar que o nosso modelo, ao passar pela média do X_i e do Y_i esteja o mais próximo de ambos
# sendo assim, podemos dizer que a linha passa pelo Y_bar e X_bar, que no caso, é o valor da média de X_i e Y_i

# %% [markdown]
# # Questão 7

# %%
# Muito difícil pra mim :(

# %% [markdown]
# # Questão 8

# %% [markdown]
# # a)

# %%
# Importação das libs 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
import os

from sklearn.linear_model import LinearRegression

# %%
# Obtenção dos dados
cwd = os.getcwd()
df = pd.read_csv(cwd + '\\..\\..\\Data\\Auto.csv')

# Definição do X e Y
x_train = df['mpg']
y_train = df['horsepower']

# Convertendo os valores de Y_train pra numéricos, pois apareceu um "?" ali no meio e a Series inteira virou object
y_train = pd.to_numeric(y_train, errors='coerce')
# Transformar os "?" na média de todos os valores
y_train.fillna(y_train.mean(), inplace=True)
# Adicionar uma constant no X_train
x_train = sm.add_constant(x_train)

# Fit no modelo
model = sm.OLS(y_train, x_train).fit()  

# Summary
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:             horsepower   R-squared:                       0.595
# Model:                            OLS   Adj. R-squared:                  0.594
# Method:                 Least Squares   F-statistic:                     580.6
# Date:                Wed, 12 Jul 2023   Prob (F-statistic):           1.45e-79
# Time:                        09:08:33   Log-Likelihood:                -1830.0
# No. Observations:                 397   AIC:                             3664.
# Df Residuals:                     395   BIC:                             3672.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        193.1312      3.877     49.808      0.000     185.508     200.754
# ...

# %% [markdown]
# # i.

# %%
# Sim, dado que nosso P-value foi baixo e nosso F-statistics foi bem maior do que 1

# %% [markdown]
# # ii.

# %%
# Relativamente alta, pois tivemos um F-statistics bem alto e um p-value bem baixo

# %% [markdown]
# # iii.

# %%
# Como visto à seguir, o coeficiente do MPG é -3, dando a entender que a relação é negativa

print(model.params)
# Out:
# const    193.131234
# mpg       -3.770299
# dtype: float64

# %% [markdown]
# # iv.

# %%
sns.regplot(y=y_train, x=df['mpg'], data=df, line_kws={'color': 'red'})

# Presença de alguns outliers(como 125,33), porém não são tantos à ponto de atrapalhar muito o
# modelo
# Out:
# <Axes: xlabel='mpg', ylabel='horsepower'>

# %% [markdown]
# # Questão 9

# %% [markdown]
# # a)

# %%
# Ajeitar a horsepower pra float e tirar os Nan values
df['horsepower'] = y_train
# 
sns.set_theme(style='ticks')
sns.pairplot(df, hue='horsepower')

# %% [markdown]
# # b)

# %%
df.corr()
# Out:
# C:\Users\Pudge\AppData\Local\Temp\ipykernel_5672\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                    mpg  cylinders  displacement  horsepower    weight  \
# mpg           1.000000  -0.776260     -0.804443   -0.771441 -0.831739
# cylinders    -0.776260   1.000000      0.950920    0.839715  0.897017
# displacement -0.804443   0.950920      1.000000    0.893833  0.933104
# horsepower   -0.771441   0.839715      0.893833    1.000000  0.860581
# weight       -0.831739   0.897017      0.933104    0.860581  1.000000
# acceleration  0.422297  -0.504061     -0.544162   -0.687039 -0.419502
# year          0.581469  -0.346717     -0.369804   -0.413022 -0.307900
# origin        0.563698  -0.564972     -0.610664   -0.453962 -0.581265
#
# ...

# %% [markdown]
# # c)

# %% [markdown]
# # i.

# %%
x_train = df.drop(columns=['name', 'mpg'])
y_train = df['mpg']

x_train = sm.add_constant(x_train)

model = sm.OLS(y_train, x_train).fit()

print(model.summary())

# Sim, temos um f-statistic bem maior do que 1 e um p-value MUITO baixo
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    mpg   R-squared:                       0.822
# Model:                            OLS   Adj. R-squared:                  0.818
# Method:                 Least Squares   F-statistic:                     256.0
# Date:                Wed, 12 Jul 2023   Prob (F-statistic):          2.41e-141
# Time:                        09:08:56   Log-Likelihood:                -1037.4
# No. Observations:                 397   AIC:                             2091.
# Df Residuals:                     389   BIC:                             2123.
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const          -18.7116      4.609     -4.060      0.000     -27.773      -9.650
# ...

# %% [markdown]
# # ii.

# %%
print(model.pvalues)
# Out:
# const           5.938216e-05
# cylinders       1.682356e-01
# displacement    1.201645e-02
# horsepower      4.788310e-01
# weight          6.675736e-23
# acceleration    2.242267e-01
# year            9.395934e-41
# origin          6.069969e-07
# dtype: float64

# %% [markdown]
# # iii.

# %%
# Como observado acima, nos pvalues, os que apresentam p-values altos, considerando um treshold,
# são Cylinders, Acceleration e HorsePower

# %% [markdown]
# # d)

# %%
influence = model.get_influence()
leverage = influence.hat_matrix_diag

plt.figure(figsize=(10, 8))
plt.scatter(range(len(leverage)), leverage, alpha=0.5)
plt.show()

# Bom, um Leverage plot não é um bom plot para identificar Outliers. Do contrário, ele nos ajuda a identificar mais
# facilmente os HLP(High Leverage Points). Nesse caso, temos ali 1 HLP

# %% [markdown]
# # e)

# %%
df['acc_year'] = df['acceleration'] * df['year']

x_train = df[['acceleration', 'year', 'acc_year']]
x_train = sm.add_constant(x_train)
model = sm.OLS(y_train, x_train).fit()

y_pred = model.predict(x_train)

sns.regplot(x=y_train, y=y_pred, line_kws={'color': 'red'})
plt.show()

# Esses dados aparentam seguir de forma Linear também.

# %% [markdown]
# # f)

# %%
df['x_squared'] = df['year']**2
x_train = df['x_squared']
x_train = sm.add_constant(x_train)

model = sm.OLS(y_train, x_train).fit()

y_pred = model.predict(x_train)

sns.scatterplot(x=df['x_squared'], y=y_train)
sns.lineplot(x=df['x_squared'], y=y_pred, color='red')
plt.show()

# Colocando ano ao quadrado não mudou nada

# %% [markdown]
# # Questão 10

# %%
cwd = os.getcwd()

df = pd.read_csv(cwd + '\\..\\..\\Data\\Carseats.csv')

# %% [markdown]
# # a)

# %%
# Transformando US em uma dummy variable
df['US'] = pd.get_dummies(df['US'], prefix=['US'], drop_first=True)
df['US'].replace(0, -1, inplace=True)

df['Urban'] = pd.get_dummies(df['Urban'], prefix=['Urban'], drop_first=True)
df['Urban'].replace(0, -1, inplace=True)

y_train = df['Sales']
x_train = df[['US', 'Urban', 'Price']]

x_train = sm.add_constant(x_train)

model = sm.OLS(y_train, x_train).fit()

print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  Sales   R-squared:                       0.239
# Model:                            OLS   Adj. R-squared:                  0.234
# Method:                 Least Squares   F-statistic:                     41.52
# Date:                Wed, 12 Jul 2023   Prob (F-statistic):           2.39e-23
# Time:                        09:08:57   Log-Likelihood:                -927.66
# No. Observations:                 400   AIC:                             1863.
# Df Residuals:                     396   BIC:                             1879.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         13.6328      0.618     22.043      0.000      12.417      14.849
# ...

# %% [markdown]
# # b)

# %%
# Baseando-se no P-value e T-value, podemos observar que o predictor US tem sim relação com o Target Value.
# Já o Urban, por ter um valor próximo ou menor que zero e um P-value consideravelmente alto, não apresenta
# tantas evidências de relação com o Target Value. No caso de Price, temos evidências estatísticas para
# dizer que ele tem significância.

# %% [markdown]
# # c)

# %%
# Equação escrita abaixo em markdown:

# %% [markdown]
# $Y = B_0 + B_1Price + B_2Urban + B_3US + ε$

# %% [markdown]
# # d)

# %%
# Nós podemos rejeitar a Null Hypothesis nos predictors US e Price, pois ambos tem valores muito pequenos de
# p-value e T-values distantes de 0.

# %% [markdown]
# # e)

# %%
# X_train usando apenas as variáveis que são importantes
x_train = df[['Price', 'US']]

# Nosso Y_train já está ajustado para valores, então
# não vou criar um novo

x_train = sm.add_constant(x_train)

model = sm.OLS(y_train, x_train).fit()

print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  Sales   R-squared:                       0.239
# Model:                            OLS   Adj. R-squared:                  0.235
# Method:                 Least Squares   F-statistic:                     62.43
# Date:                Wed, 12 Jul 2023   Prob (F-statistic):           2.66e-24
# Time:                        09:08:57   Log-Likelihood:                -927.66
# No. Observations:                 400   AIC:                             1861.
# Df Residuals:                     397   BIC:                             1873.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         13.6306      0.617     22.089      0.000      12.417      14.844
# ...

# %% [markdown]
# # f)

# %%
# No teste E temos um F-statistic maior e um P-value menor do que no teste A, porém, o R² não alterou muito

# %% [markdown]
# # g)

# %%
model.conf_int()
# Out:
#               0          1
# const  12.41744  14.843789
# Price  -0.06476  -0.044195
# US      0.34576   0.853883

# %% [markdown]
# # h)

# %%
# Atribuindo model em results para facilitar a criação do código
results = model

# Pegando results e residuals
residuals = results.resid
leverage = results.get_influence().hat_matrix_diag

# Todo o cálculo que é feito dos outliers e leverage points baseados em um treshold de 3 e 2, respectivamente
outlier_threshold = np.abs(residuals).mean() + 3 * np.abs(residuals).std()
leverage_threshold = 2*(x_train.shape[1])/x_train.shape[0]

# Capturando apenas aqueles que são maiores que o threshold, ou seja, os respectivos outliers e high leverage
# points
outlier_indices = np.where(np.abs(residuals) > outlier_threshold)
high_leverage_indices = np.where(leverage > leverage_threshold)

# Printando os outliers e high leverage points dado um treshold
print('Outliers:', outlier_indices)
print('High-leverage points:', high_leverage_indices)
# Out:
# Outliers: (array([ 50,  68, 376], dtype=int64),)
# High-leverage points: (array([ 42, 125, 155, 156, 159, 165, 171, 174, 191, 203, 208, 269, 272,
#        313, 315, 356, 365, 367, 383, 386], dtype=int64),)

# %% [markdown]
# # Questão 11

# %% [markdown]
# # a)

# %%
# Criação dos dados
x = np.random.normal(size=100)
y = 2 * x + (np.random.normal(size=100))

x = sm.add_constant(x)

model = sm.OLS(y,x).fit()

print(model.summary())

# B_0_hat tem um valor de 2.0368, with a STD-Error of 0.092, T-statistic of 22.186 and p-value of
# 0.240. Podemos observar que para cada unidade de X, o Y aumenta em 2.0368, já para o standard error,
# podemos identificar que, por ele ser baixo em relação ao coef, esse coef está próximo da true relationship
# t-statistics é maior do que zero, o que nos indica que muito provavelmente existe uma relação
# entre o predictor e o target value e o seu p-value é muito baixo, descaracterizando assim a Null Hypothesis
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.817
# Model:                            OLS   Adj. R-squared:                  0.815
# Method:                 Least Squares   F-statistic:                     438.0
# Date:                Wed, 12 Jul 2023   Prob (F-statistic):           6.16e-38
# Time:                        09:08:57   Log-Likelihood:                -135.66
# No. Observations:                 100   AIC:                             275.3
# Df Residuals:                      98   BIC:                             280.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0726      0.095     -0.762      0.448      -0.261       0.116
# ...

# %% [markdown]
# # b)

# %%
x = np.random.normal(size=100)
y = 2 * x + (np.random.normal(size=100))

y = sm.add_constant(y)

model = sm.OLS(x,y).fit()

print(model.summary())

# Temos as mesmas impressões da anterior
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.759
# Model:                            OLS   Adj. R-squared:                  0.756
# Method:                 Least Squares   F-statistic:                     308.0
# Date:                Wed, 12 Jul 2023   Prob (F-statistic):           5.19e-32
# Time:                        09:08:57   Log-Likelihood:                -65.900
# No. Observations:                 100   AIC:                             135.8
# Df Residuals:                      98   BIC:                             141.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0349      0.047     -0.738      0.462      -0.129       0.059
# ...

# %% [markdown]
# # c)

# %%
# Ambos são muito parecidos, já que tem p-values baixos, t-statistics diferentes de 0 e standard errors
# próximos do Coef.

# %% [markdown]
# # d)

# %%
# R.I.P

# %% [markdown]
# # e)

# %%
# R.I.P

# %% [markdown]
# # f)

# %%
x = np.array([1, 2, 3, 4, 5])
y = np.array([1, 2, 3, 4, 5])

# Regressão de Y em X
X = sm.add_constant(x)
model = sm.OLS(y,X).fit()
yinx = model.tvalues[1]
print(f"Regressão de Y em X = {yinx}")

# Regressão de X em Y
Y = sm.add_constant(y)
model = sm.OLS(x, Y).fit()
xiny = model.tvalues[1]
print(f"Regressão de X em Y = {xiny}")

# Como os resultados monstram, é a mesma sim
# Out:
# Regressão de Y em X = 4111205176471134.0
# Regressão de X em Y = 4111205176471134.0

# %% [markdown]
# # Questão 12

# %% [markdown]
# # a)

# %%
# Para que o B_1_Hat seja igual tanto pra X em Y e Y em X, precisamos que Xi^2 seja igual a Yi^2
# já que o outro somatório usa X e Y juntos

# %% [markdown]
# # b)

# %%
x = np.random.normal(size=100)
y = np.random.normal(size=100)

x = sm.add_constant(x)

model = sm.OLS(y, x).fit()

print(model.summary())

# Nesse caso é diferente, pois o X e Y são diferentes
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.020
# Model:                            OLS   Adj. R-squared:                  0.010
# Method:                 Least Squares   F-statistic:                     2.012
# Date:                Wed, 12 Jul 2023   Prob (F-statistic):              0.159
# Time:                        09:08:57   Log-Likelihood:                -132.96
# No. Observations:                 100   AIC:                             269.9
# Df Residuals:                      98   BIC:                             275.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0067      0.093     -0.072      0.943      -0.190       0.177
# ...

# %%
x = np.random.normal(size=100)
y = x

x = sm.add_constant(x)

model = sm.OLS(y, x).fit()

print(model.summary())

# Nesse caso é igual, pois o X e Y são iguais
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 2.019e+33
# Date:                Wed, 12 Jul 2023   Prob (F-statistic):               0.00
# Time:                        09:08:57   Log-Likelihood:                 3481.3
# No. Observations:                 100   AIC:                            -6959.
# Df Residuals:                      98   BIC:                            -6953.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -3.469e-17   1.87e-17     -1.854      0.067   -7.18e-17    2.45e-18
# ...

# %% [markdown]
# # Questão 13

# %% [markdown]
# # a)

# %%
np.random.seed(1)
x = np.random.normal(0, 1, 100)

# %% [markdown]
# # b)

# %%
np.random.seed(1)
eps = np.random.normal(0,0.25,100)

# %% [markdown]
# # c)

# %%
Y = -1 + 0.5*x + eps

Y = np.array(Y)

# Y tem um tamanho 100, dado que usamos 100 amostras de cada X e Eps. B_0 é -1 e B_1 é 0.5

# %% [markdown]
# # d)

# %%
sns.regplot(x=x, y=Y, line_kws={'color': 'red'})

# Disposição dos dados totalmente linear
# Out:
# <Axes: >

# %% [markdown]
# # e)

# %%
x_e = sm.add_constant(x)

model = sm.OLS(Y, x_e).fit()

print(model.summary())

# O B_0_hat tem o mesmo valor de -1 e o B_1_hat chega bem próximo, sendo ele 0.75 e o B_0 0.5
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 1.336e+33
# Date:                Wed, 12 Jul 2023   Prob (F-statistic):               0.00
# Time:                        09:08:58   Log-Likelihood:                 3483.6
# No. Observations:                 100   AIC:                            -6963.
# Df Residuals:                      98   BIC:                            -6958.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -1.0000   1.82e-17  -5.49e+16      0.000      -1.000      -1.000
# ...

# %% [markdown]
# # f)

# %%
# Acabou que eu já tinha feito na D e.e

# %% [markdown]
# # g)

# %%
import statsmodels.formula.api as smf

x_2 = x**2

x = pd.Series(x)
x_2 = pd.Series(x_2)
Y = pd.Series(Y)

df = pd.concat([x, x_2, Y])

model = smf.ols(formula='Y ~ x + x_2', data=df).fit()

print(model.summary())

# Dado um p-value consideravelmente alto e um T-statistics bem próximo de 0, podemos inferir
# que ele não agrega ao nosso modelo
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      Y   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 5.234e+31
# Date:                Wed, 12 Jul 2023   Prob (F-statistic):               0.00
# Time:                        09:08:58   Log-Likelihood:                 3356.8
# No. Observations:                 100   AIC:                            -6708.
# Df Residuals:                      97   BIC:                            -6700.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -1.0000   7.95e-17  -1.26e+16      0.000      -1.000      -1.000
# ...

# %% [markdown]
# # Questão 14

# %% [markdown]
# # a)

# %%
np.random.seed(1)

# runif()
x1 = np.random.uniform(low=0.0, high=1.0, size=100)
# rnorm()
x2 = 0.5 * x1 + np.random.normal(loc=0.0, scale=1.0, size=100) / 10

# Function
y = 2 + 2 * x1 + 0.3 * x2 + np.random.normal(loc=0.0, scale=1.0, size=100)

# error = rnorm(100) , B_0 = 2, B_1 = 2, B_2 = 0.3

# %% [markdown]
# # b)

# %%
sns.scatterplot(x=x1, y=x2)

# A correlação do x1 e x2 é bem próxima de linear
# Out:
# <Axes: >

# %% [markdown]
# # c)

# %%
x1 = pd.Series(x1)
x2 = pd.Series(x2)
y = pd.Series(y)

df = pd.concat([x1, x2, y], axis=1)
df.columns = ['x1', 'x2', 'y']

x_train = df.drop('y', axis=1)
y_train = df['y']

x_train = sm.add_constant(x_train)

model = sm.OLS(y_train, x_train).fit()

print(model.summary())

# B_0_hat é 2.18, B_1_hat 0.70 e B_2_hat 2.50.
# Não podemos rejeitar null hypothesis para B_0 já que ele tem um p-value
# consideravelmente alto e t-statistics baixa
# Também não podemos rejeitar B_2 pelos mesmos motivos
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.261
# Model:                            OLS   Adj. R-squared:                  0.245
# Method:                 Least Squares   F-statistic:                     17.09
# Date:                Wed, 12 Jul 2023   Prob (F-statistic):           4.40e-07
# Time:                        09:08:58   Log-Likelihood:                -142.34
# No. Observations:                 100   AIC:                             290.7
# Df Residuals:                      97   BIC:                             298.5
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.1893      0.199     11.021      0.000       1.795       2.584
# ...

# %% [markdown]
# # d)

# %%
x1_d = sm.add_constant(x1)

model = sm.OLS(y, x1_d).fit()

print(model.summary())

# Nesse caso podemos rejeitar null hypothesis, já que o P-value é consideravelmente
# baixo e o t-statistics consideravelmente distante de 0
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.224
# Model:                            OLS   Adj. R-squared:                  0.216
# Method:                 Least Squares   F-statistic:                     28.26
# Date:                Wed, 12 Jul 2023   Prob (F-statistic):           6.68e-07
# Time:                        09:08:58   Log-Likelihood:                -144.76
# No. Observations:                 100   AIC:                             293.5
# Df Residuals:                      98   BIC:                             298.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.2486      0.201     11.209      0.000       1.850       2.647
# ...

# %% [markdown]
# # e)

# %%
x2_e = sm.add_constant(x2)

model = sm.OLS(y, x2_e).fit()

print(model.summary())

# Nesse caso também podemos rejeitar null hypothesis por conta do P-value e T-statistics
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.251
# Model:                            OLS   Adj. R-squared:                  0.244
# Method:                 Least Squares   F-statistic:                     32.87
# Date:                Wed, 12 Jul 2023   Prob (F-statistic):           1.09e-07
# Time:                        09:08:58   Log-Likelihood:                -142.97
# No. Observations:                 100   AIC:                             289.9
# Df Residuals:                      98   BIC:                             295.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.2655      0.187     12.145      0.000       1.895       2.636
# ...

# %% [markdown]
# # f)

# %%
# Sim, elas se contradizem muito provavelmente por haver colinearidade entre
# os predictors

# %% [markdown]
# # g)

# %%
x1 = x1.append(pd.Series(0.1)).reset_index(drop=True)
x1_g = sm.add_constant(x1)

x2 = x2.append(pd.Series(0.8)).reset_index(drop=True)
x2_g = sm.add_constant(x2)

y = y.append(pd.Series(6)).reset_index(drop=True)
# Out:
# C:\Users\Pudge\AppData\Local\Temp\ipykernel_5672\3576362943.py:1: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   x1 = x1.append(pd.Series(0.1)).reset_index(drop=True)
# C:\Users\Pudge\AppData\Local\Temp\ipykernel_5672\3576362943.py:4: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   x2 = x2.append(pd.Series(0.8)).reset_index(drop=True)
# C:\Users\Pudge\AppData\Local\Temp\ipykernel_5672\3576362943.py:7: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   y = y.append(pd.Series(6)).reset_index(drop=True)

# %%
model1 = sm.OLS(y, x1_g).fit()

model2 = sm.OLS(y, x2_g).fit()

sns.regplot(x=x1, y=y, line_kws={'color': 'red'})
plt.show()

sns.regplot(x=x2, y=y, line_kws={'color': 'red'})

# Para a primeira modificação, podemos notar uma piora não muito significante
# no nosso modelo. 

# Cada um desses dados são outliers, pois estão distantes entre X e Y
# Out:
# <Axes: >

# %% [markdown]
# # Questão 15

# %% [markdown]
# # a)

# %%
cwd = os.getcwd()

df = pd.read_csv(cwd + '\\..\\..\\Data\\Boston.csv')

simple_coef = []

predictors = df.columns.tolist()
predictors.remove('crim')

for predictor in predictors:
    model = sm.OLS(df['crim'], sm.add_constant(df[predictor]))
    results = model.fit()
    print(results.summary())
    simple_coef.append(results.params[predictor])

    sns.regplot(x=predictor, y='crim', data=df, line_kws={'color': 'red'})
    plt.title(f'Linear Regression: crim vs {predictor}')
    plt.show()

# Para Zn, estatisticamente existe relação
# Para Indus, estatisticamente existe relação
# Para Chas, estatisticamente não existe relação
# Para Nox, estatisticamente existe relação
# Para Rm, estatisticamente existe relação
# Para Age, estatisticamente existe relação
# Para Dis, estatisticamente existe relação
# Para Rad, estatisticamente existe relação
# Para Tax, estatisticamente existe relação
# Para Ptratio, estatisticamente existe relação
# Para Black, estatisticamente existe relação
# Para Lstat, estatisticamente existe relação
# Para Medv, estatisticamente existe relação
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                   crim   R-squared:                       0.040
# Model:                            OLS   Adj. R-squared:                  0.038
# Method:                 Least Squares   F-statistic:                     21.10
# Date:                Wed, 12 Jul 2023   Prob (F-statistic):           5.51e-06
# Time:                        10:25:19   Log-Likelihood:                -1796.0
# No. Observations:                 506   AIC:                             3596.
# Df Residuals:                     504   BIC:                             3604.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          4.4537      0.417     10.675      0.000       3.634       5.273
# ...

# %% [markdown]
# # b)

# %%
y_train = df['crim']

x_train = df.drop('crim', axis=1)
x_train = sm.add_constant(x_train)

model = sm.OLS(y_train, x_train).fit()

multiple_coef = list(model.params)
multiple_coef.remove(multiple_coef[0])

print(model.summary())
# Podemos estatisticamente rejeitar nos predictors: rad, const, zn, nox, dis, ptratio, black, medv, lstat
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                   crim   R-squared:                       0.454
# Model:                            OLS   Adj. R-squared:                  0.440
# Method:                 Least Squares   F-statistic:                     31.47
# Date:                Wed, 12 Jul 2023   Prob (F-statistic):           1.57e-56
# Time:                        10:32:40   Log-Likelihood:                -1653.3
# No. Observations:                 506   AIC:                             3335.
# Df Residuals:                     492   BIC:                             3394.
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         17.0332      7.235      2.354      0.019       2.818      31.248
# ...

# %% [markdown]
# # c)

# %%
x_train = simple_coef
y_train = multiple_coef

model = sm.OLS(y_train, sm.add_constant(x_train)).fit()

sns.scatterplot(y=y_train, x=x_train)

# A comparação entre A e B é que chas foi rejeitado em ambos
# Out:
# <Axes: >

# %%
predictors = df.columns.tolist()
predictors.remove('crim')

y_train = df['crim']

for predictor in predictors:
    x_train = np.polynomial.polynomial.polyvander(df[predictor], 3)[:, 1:]
    
    x_train = sm.add_constant(x_train)

    model = sm.OLS(y_train, x_train).fit()

    print(f'{predictor}: {model.summary()}\n\n')

# O que não tem evidência é o Chas
# Out:
# zn:                             OLS Regression Results
# ...
# Dep. Variable:                   crim   R-squared:                       0.058
# Model:                            OLS   Adj. R-squared:                  0.053
# Method:                 Least Squares   F-statistic:                     10.35
# Date:                Wed, 12 Jul 2023   Prob (F-statistic):           1.28e-06
# Time:                        11:42:56   Log-Likelihood:                -1791.2
# No. Observations:                 506   AIC:                             3590.
# Df Residuals:                     502   BIC:                             3607.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          4.8461      0.433     11.192      0.000       3.995       5.697
# ...
