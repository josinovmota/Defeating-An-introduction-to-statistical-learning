# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LassoCV

# %% [markdown]
# # Questão 8

# %% [markdown]
# # a)

# %%
# Create a predictor X
X = np.random.default_rng().normal(size=100)
# Create a Noise Vector e
e = np.random.default_rng().normal(size=100)

# %% [markdown]
# # b)

# %%
B_0 = 0.5
B_1 = -0.3
B_2 = 3
B_3 = 0.7

Y = B_0 + B_1 * X + B_2 * (X ** 2) + B_3 * (X ** 3) + e

# %% [markdown]
# # c)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def forward_stepwise(X, Y):
    features = np.array([X**i for i in range(1, 11)]).T

    best_rss_set = []
    best_features_idx = []
    best_cp = np.inf
    best_model_features = []
    # rever
    full_model = LinearRegression().fit(features, Y)
    sigma_hat_squared = mean_squared_error(Y, full_model.predict(features))

    features_idx = [i for i in range(features.shape[1])]

    while features_idx:
        best_rss = None
        best_idx = None
        for feature_idx in features_idx:
            features_set = features[:, best_features_idx + [feature_idx]]
            model = LinearRegression().fit(features_set,Y)
            y_pred = model.predict(features_set)
            Rss = np.sum((Y - y_pred)**2)

            if best_rss is None or Rss < best_rss:
                best_rss = Rss
                best_idx = feature_idx

        best_rss_set.append(best_rss)
        best_features_idx.append(best_idx)
        features_idx.remove(best_idx)

        p = len(best_features_idx) + 1

        n = 100

        # rever como é o cálculo do c_p statistics que o livro pede
        c_p = (best_rss + 2 * p * sigma_hat_squared) / n

        if c_p < best_cp:
            best_cp = c_p
            best_model_features = list(best_features_idx)
            final_model = LinearRegression().fit(features[:, best_features_idx], Y)
            coefficients = final_model.coef_

        print(f'O c_p statistics de {best_features_idx} é {c_p}')

    print(f'\nO modelo selecionado de acordo com o c_p statistics é:{best_model_features}, e os coeficientes são: {coefficients}')

forward_stepwise(X, Y)
# Out:
# O c_p statistics de [1] é 3.0493241855124675
# O c_p statistics de [1, 2] é 0.9662430635314441
# O c_p statistics de [1, 2, 0] é 0.9517398613734414
# O c_p statistics de [1, 2, 0, 8] é 0.9452678086671286
# O c_p statistics de [1, 2, 0, 8, 3] é 0.9540425815567989
# O c_p statistics de [1, 2, 0, 8, 3, 5] é 0.9561710939132503
# O c_p statistics de [1, 2, 0, 8, 3, 5, 9] é 0.9693568109884707
# O c_p statistics de [1, 2, 0, 8, 3, 5, 9, 4] é 0.9836923890167291
# O c_p statistics de [1, 2, 0, 8, 3, 5, 9, 4, 6] é 0.990027626538114
# O c_p statistics de [1, 2, 0, 8, 3, 5, 9, 4, 6, 7] é 1.0041789258149487
#
# O modelo selecionado de acordo com o c_p statistics é:[1, 2, 0, 8], e os coeficientes são: [ 3.02357520e+00  8.39674217e-01 -5.37545970e-01 -8.25521463e-04]

# %% [markdown]
# # d)

# %%
def backward_stepwise(X, Y):
    features = np.array([X**i for i in range(1, 11)]).T

    full_features_idx = [i for i in range(features.shape[1])]

    full_model = LinearRegression().fit(features, Y)
    sigma_hat_squared = mean_squared_error(Y, full_model.predict(features))

    best_features_idx = []
    best_rss_set = []
    best_cp = np.inf

    while len(full_features_idx) > 1:
        best_rss = None
        best_idx = None
        for feature_idx in full_features_idx:
            x = full_features_idx.copy()
            x.remove(feature_idx)
            features_set = features[:, x]
            model = LinearRegression().fit(features_set, Y)
            y_pred = model.predict(features_set)
            Rss = np.sum((Y - y_pred)**2)

            if best_rss is None or Rss < best_rss:
                best_rss = Rss
                best_idx = feature_idx 
        
        full_features_idx.remove(best_idx)
        best_rss_set.append(best_rss)
        best_features_idx.append(best_idx)

        p = len(full_features_idx)

        n = 100

        # rever como é o cálculo do c_p statistics que o livro pede
        c_p = (best_rss + 2 * p * sigma_hat_squared) / n

        if c_p < best_cp:
            # melhor c_p
            best_cp = c_p
            # lista de features com menor RSS
            best_model_features = list(full_features_idx)
            # Modelo final feito com a lista de features com menor RSS
            final_model = LinearRegression().fit(features[:, best_model_features], Y)
            # Coeficientes desse modelo
            coefficients = final_model.coef_

        print(f'O c_p statistics de {full_features_idx} é {c_p}')

    print(f'\nO modelo selecionado de acordo com o c_p statistics é:{best_model_features}, e os coeficientes são: {coefficients}')

backward_stepwise(X, Y)

"""
As resposta são iguais :O
# Out:
# O c_p statistics de [0, 1, 2, 4, 5, 6, 7, 8, 9] é 0.9715629683429952
# O c_p statistics de [1, 2, 4, 5, 6, 7, 8, 9] é 0.9554900220754975
# O c_p statistics de [1, 2, 4, 5, 6, 7, 8] é 0.9513374121533709
# O c_p statistics de [1, 2, 4, 5, 6, 7] é 0.9444847824671899
# O c_p statistics de [1, 4, 5, 6, 7] é 0.9291708322968462
# O c_p statistics de [1, 4, 5, 6] é 0.9240320446350035
# O c_p statistics de [1, 4, 6] é 0.9165553192844409
# O c_p statistics de [1, 4] é 1.159652350712543
# O c_p statistics de [1] é 3.032862235908944
#
# O modelo selecionado de acordo com o c_p statistics é:[1, 4, 6], e os coeficientes são: [ 3.06697234  0.33486569 -0.04002484]

# %% [markdown]
# # e)

# %%
features_set = np.array([X**i for i in range(1, 11)]).T

alphas = np.logspace(-6, 6, 100)
lasso_cv = LassoCV(alphas=alphas, cv=5, random_state=0)

lasso_cv.fit(features_set, Y)

best_alpha = lasso_cv.alpha_
print("Best alpha:", best_alpha)
# Out:
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 27.28197379177999, tolerance: 19.577543587486012
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 31.663329869967043, tolerance: 19.577543587486012
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 30.327414400080954, tolerance: 19.577543587486012
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 26.364102722044834, tolerance: 19.577543587486012
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 21.65007515523314, tolerance: 19.577543587486012
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 28.803997679120712, tolerance: 19.577543587486012
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 35.164288336386704, tolerance: 19.577543587486012
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 37.01970195717336, tolerance: 19.577543587486012
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 37.09414157661945, tolerance: 19.577543587486012
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 33.48566029213265, tolerance: 19.577543587486012
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 31.405799876259138, tolerance: 19.577543587486012
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 29.78027321939065, tolerance: 19.577543587486012
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 28.77609366299866, tolerance: 19.577543587486012
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 28.330439260304658, tolerance: 19.577543587486012
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 28.337516095802364, tolerance: 19.577543587486012
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 27.525290108398686, tolerance: 19.577543587486012
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 26.174004943718856, tolerance: 19.577543587486012
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 25.14390795556713, tolerance: 19.577543587486012
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 24.463365001360508, tolerance: 19.577543587486012
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 24.000726340513083, tolerance: 19.577543587486012
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 23.6758024277605, tolerance: 19.577543587486012
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 23.44229008250236, tolerance: 19.577543587486012
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 23.272277547614934, tolerance: 19.577543587486012
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 23.148033612959203, tolerance: 19.577543587486012
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 23.05791267221057, tolerance: 19.577543587486012
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 23.066667815785195, tolerance: 19.577543587486012
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 23.97244673684866, tolerance: 19.577543587486012
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 31.69292130194001, tolerance: 19.577543587486012
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 34.18678402108796, tolerance: 19.577543587486012
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 34.89947359018092, tolerance: 19.577543587486012
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 35.22502724753448, tolerance: 19.577543587486012
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 35.405430366596704, tolerance: 19.577543587486012
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 35.516823140508635, tolerance: 19.577543587486012
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 35.55743441693228, tolerance: 19.577543587486012
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 35.61561012953737, tolerance: 19.577543587486012
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 35.663384645753816, tolerance: 19.577543587486012
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 35.70190951851867, tolerance: 19.577543587486012
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 35.73211946227207, tolerance: 19.577543587486012
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 35.755123063604316, tolerance: 19.577543587486012
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 35.77249297726096, tolerance: 19.577543587486012
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 35.78562337272818, tolerance: 19.577543587486012
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 35.795594494004575, tolerance: 19.577543587486012
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 35.80320018667317, tolerance: 19.577543587486012
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 35.809010850696765, tolerance: 19.577543587486012
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 35.81343174279502, tolerance: 19.577543587486012
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 35.81674717222117, tolerance: 19.577543587486012
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 35.8191504391922, tolerance: 19.577543587486012
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 35.823357754333166, tolerance: 19.577543587486012
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 35.82895312579737, tolerance: 19.577543587486012
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 35.83295984889025, tolerance: 19.577543587486012
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 35.83577423354534, tolerance: 19.577543587486012
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 35.83769201603093, tolerance: 19.577543587486012
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 35.838934981549116, tolerance: 19.577543587486012
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 35.83967008827982, tolerance: 19.577543587486012
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 35.84002352821788, tolerance: 19.577543587486012
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 35.84009027435521, tolerance: 19.577543587486012
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 35.839942492607996, tolerance: 19.577543587486012
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5.2640931589858155, tolerance: 2.530722541186477
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5.209521186053621, tolerance: 2.530722541186477
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.0064365581966115, tolerance: 2.530722541186477
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.925490189539687, tolerance: 2.530722541186477
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5.237312874692229, tolerance: 2.530722541186477
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.102907639829937, tolerance: 2.530722541186477
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 4.832933313794648, tolerance: 2.530722541186477
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.6392428558067, tolerance: 2.530722541186477
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 14.89419869602495, tolerance: 2.530722541186477
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 12.286579355900002, tolerance: 2.530722541186477
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 29.032345046268638, tolerance: 2.530722541186477
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 33.83727855535195, tolerance: 2.530722541186477
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 35.930854504681776, tolerance: 2.530722541186477
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 38.368939432874, tolerance: 2.530722541186477
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 39.30519907730452, tolerance: 2.530722541186477
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 39.69181475242753, tolerance: 2.530722541186477
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 39.83711719889657, tolerance: 2.530722541186477
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 39.86532875649902, tolerance: 2.530722541186477
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 39.833799576408914, tolerance: 2.530722541186477
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 39.77161459312063, tolerance: 2.530722541186477
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 39.69158302121379, tolerance: 2.530722541186477
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 39.62027216720754, tolerance: 2.530722541186477
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 39.54356323696986, tolerance: 2.530722541186477
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 39.46584355900879, tolerance: 2.530722541186477
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 39.39004443644292, tolerance: 2.530722541186477
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 39.31787908551148, tolerance: 2.530722541186477
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 39.25027689778814, tolerance: 2.530722541186477
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 39.18765869306448, tolerance: 2.530722541186477
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 39.13011716664403, tolerance: 2.530722541186477
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 39.07753795021455, tolerance: 2.530722541186477
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 39.029681584190556, tolerance: 2.530722541186477
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 38.986238925235575, tolerance: 2.530722541186477
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 38.94686818843215, tolerance: 2.530722541186477
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 38.91121922325024, tolerance: 2.530722541186477
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 38.87894894474339, tolerance: 2.530722541186477
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 38.84973067023418, tolerance: 2.530722541186477
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 38.82325931451082, tolerance: 2.530722541186477
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 38.79925381452561, tolerance: 2.530722541186477
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 38.77745776172988, tolerance: 2.530722541186477
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 38.75763889627997, tolerance: 2.530722541186477
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 38.739587916161355, tolerance: 2.530722541186477
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 38.72311691143008, tolerance: 2.530722541186477
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 38.7080576503549, tolerance: 2.530722541186477
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 38.694259798100425, tolerance: 2.530722541186477
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 27.171042947418584, tolerance: 19.636031765214618
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 34.857508800474704, tolerance: 19.636031765214618
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 34.2577028136933, tolerance: 19.636031765214618
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 29.79019091044279, tolerance: 19.636031765214618
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 24.133927954067417, tolerance: 19.636031765214618
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 25.51260659473516, tolerance: 19.636031765214618
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 31.662927425027917, tolerance: 19.636031765214618
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 33.88346256170993, tolerance: 19.636031765214618
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 34.340914679069144, tolerance: 19.636031765214618
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 31.92052326738132, tolerance: 19.636031765214618
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 30.227381321935056, tolerance: 19.636031765214618
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 28.520854709244723, tolerance: 19.636031765214618
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 27.306608263097722, tolerance: 19.636031765214618
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 26.61504952865117, tolerance: 19.636031765214618
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 26.389014529819285, tolerance: 19.636031765214618
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 26.561512466198266, tolerance: 19.636031765214618
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 27.068297168664905, tolerance: 19.636031765214618
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 27.846649337222892, tolerance: 19.636031765214618
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 25.648405848784734, tolerance: 19.636031765214618
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 24.803333891947737, tolerance: 19.636031765214618
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 26.289177252582945, tolerance: 19.636031765214618
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 27.690611098652397, tolerance: 19.636031765214618
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 27.57795958073698, tolerance: 19.636031765214618
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 27.377678310628333, tolerance: 19.636031765214618
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 27.198081160129426, tolerance: 19.636031765214618
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 24.615052297399764, tolerance: 19.636031765214618
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 27.274886115957663, tolerance: 19.636031765214618
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 33.238884839822376, tolerance: 19.636031765214618
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 38.042317452792894, tolerance: 19.636031765214618
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 39.06713730974793, tolerance: 19.636031765214618
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 39.1327123084662, tolerance: 19.636031765214618
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 39.59274174531774, tolerance: 19.636031765214618
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 39.797069674434475, tolerance: 19.636031765214618
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 39.905578545700685, tolerance: 19.636031765214618
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 39.975485424332724, tolerance: 19.636031765214618
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 40.01937232403661, tolerance: 19.636031765214618
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 40.04571187528549, tolerance: 19.636031765214618
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 40.06194120983364, tolerance: 19.636031765214618
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 40.071515767382024, tolerance: 19.636031765214618
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 40.077011149964136, tolerance: 19.636031765214618
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 40.07996100000679, tolerance: 19.636031765214618
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 40.08130011752667, tolerance: 19.636031765214618
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 40.081580760510896, tolerance: 19.636031765214618
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 40.08110465800323, tolerance: 19.636031765214618
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 40.079997729917345, tolerance: 19.636031765214618
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 40.07823955283835, tolerance: 19.636031765214618
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 40.075641982580976, tolerance: 19.636031765214618
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 40.071733224798294, tolerance: 19.636031765214618
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 40.067017466928, tolerance: 19.636031765214618
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 40.07523213252813, tolerance: 19.636031765214618
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 40.08115031068357, tolerance: 19.636031765214618
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 40.08533449971373, tolerance: 19.636031765214618
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 40.0882059413815, tolerance: 19.636031765214618
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 40.090082276317155, tolerance: 19.636031765214618
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 40.091204206184244, tolerance: 19.636031765214618
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 40.091754720873745, tolerance: 19.636031765214618
#   model = cd_fast.enet_coordinate_descent_gram(
# ...
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 41.48647527631697, tolerance: 19.60225522050893
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 38.33270164785773, tolerance: 19.60225522050893
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 35.391485777983846, tolerance: 19.60225522050893
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 33.13630619815076, tolerance: 19.60225522050893
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 31.607607969161073, tolerance: 19.60225522050893
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 30.727299649115018, tolerance: 19.60225522050893
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 30.387755105350003, tolerance: 19.60225522050893
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 29.616139214924658, tolerance: 19.60225522050893
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 30.09684479509005, tolerance: 19.60225522050893
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 27.575609674553597, tolerance: 19.60225522050893
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 27.082760441874484, tolerance: 19.60225522050893
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 26.725486647094577, tolerance: 19.60225522050893
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 25.849921136346993, tolerance: 19.60225522050893
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 27.495685426272082, tolerance: 19.60225522050893
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 28.62033790239302, tolerance: 19.60225522050893
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 31.771258244105915, tolerance: 19.60225522050893
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 28.904939345491762, tolerance: 19.60225522050893
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 30.846257916132068, tolerance: 19.60225522050893
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 34.26574605934865, tolerance: 19.60225522050893
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 36.19881977596307, tolerance: 19.60225522050893
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 36.83890745403518, tolerance: 19.60225522050893
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 37.08510293047514, tolerance: 19.60225522050893
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 37.176152183544524, tolerance: 19.60225522050893
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 37.20187891943186, tolerance: 19.60225522050893
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 37.19677350919005, tolerance: 19.60225522050893
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 37.166156242643176, tolerance: 19.60225522050893
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 37.15071452443486, tolerance: 19.60225522050893
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 37.13482060465589, tolerance: 19.60225522050893
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 37.11749948139283, tolerance: 19.60225522050893
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 37.10083376086761, tolerance: 19.60225522050893
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 37.08583027004247, tolerance: 19.60225522050893
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 37.07287084176666, tolerance: 19.60225522050893
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 37.06198645503719, tolerance: 19.60225522050893
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 37.05302343199626, tolerance: 19.60225522050893
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 37.04574306553134, tolerance: 19.60225522050893
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 37.03987955835136, tolerance: 19.60225522050893
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 37.035171704227935, tolerance: 19.60225522050893
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 37.03137805637756, tolerance: 19.60225522050893
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 37.02828154424208, tolerance: 19.60225522050893
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 37.02568684422109, tolerance: 19.60225522050893
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 37.02341131899729, tolerance: 19.60225522050893
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 37.021271809934966, tolerance: 19.60225522050893
#   model = cd_fast.enet_coordinate_descent_gram(
# Best alpha: 0.01
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 37.01902976377577, tolerance: 19.60225522050893
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 37.016324300329565, tolerance: 19.60225522050893
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 37.013169075192124, tolerance: 19.60225522050893
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 37.01637858812582, tolerance: 19.60225522050893
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 37.0187397679956, tolerance: 19.60225522050893
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 37.02043967943841, tolerance: 19.60225522050893
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 37.02162480638071, tolerance: 19.60225522050893
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 37.02241001853826, tolerance: 19.60225522050893
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:614: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 37.02288538385433, tolerance: 19.60225522050893
#   model = cd_fast.enet_coordinate_descent_gram(
# c:\Users\Josino\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.221e+01, tolerance: 1.972e+01
#   model = cd_fast.enet_coordinate_descent(

# %% [markdown]
# # f)

# %%
B_7 = 0.3

Y = B_0 + B_7 * (X**7) + e

forward_stepwise(X, Y)

X_lasso = X.reshape(-1, 1)

lasso = Lasso(alpha=1)
lasso.fit(X_lasso, Y)
y_pred = lasso.predict(X_lasso)
mse = mean_squared_error(Y, y_pred)

print('\n')
print(mse)
print("Coefficients:", lasso.coef_)
# Out:
# O c_p statistics de [0] é 3.228264278955905
# O c_p statistics de [0, 1] é 4.35050809910263
# O c_p statistics de [0, 1, 4] é 5.471390269423357
# O c_p statistics de [0, 1, 4, 2] é 6.592439196098963
# O c_p statistics de [0, 1, 4, 2, 3] é 7.709233804324487
# O c_p statistics de [0, 1, 4, 2, 3, 5] é 20.813998692194165
# O c_p statistics de [0, 1, 4, 2, 3, 5, 6] é 26.120624403880687
# O c_p statistics de [0, 1, 4, 2, 3, 5, 6, 7] é 27.576585385623783
# O c_p statistics de [0, 1, 4, 2, 3, 5, 6, 7, 8] é 29.58819017153588
# O c_p statistics de [0, 1, 4, 2, 3, 5, 6, 7, 8, 9] é 68.47996378602879
#
# O modelo selecionado de acordo com o c_p statistics é:[0], e os coeficientes são: [0.29923597]
#
#
# 1616.586392639712
# Coefficients: [17.49769444]
